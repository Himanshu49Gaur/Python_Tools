# %% [markdown]
# # Web3 Trading Analytics: Advanced Predictive Modeling & Strategy Backtesting
#
# **Colab Notebook:** `notebook_2.ipynb`
# **Topic:** Machine Learning Strategy & Regime Classification Signals

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('csv_files/merged_trader_sentiment.csv')
print('Loaded merged dataset for strategy backtesting:', df.shape)
